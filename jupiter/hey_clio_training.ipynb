# %% [markdown]
# # Hey Clio Training Starter
#
# Use this notebook as a launcher and checklist for training your custom `hey clio` wake-word model with the local `micro-wake-word` repo.

# %%
from pathlib import Path
import sys

workspace_repo = Path('/Users/filippospirpilidis/Projects/wakewords-models')
training_repo = Path('/Users/filippospirpilidis/Projects/wakewords-models/jupiter/micro-wake-word')
training_notebook = training_repo / 'notebooks' / 'basic_training_notebook.ipynb'
target_word = 'hey Clio'

print('Kernel Python:', sys.executable)
print('Workspace repo:', workspace_repo)
print('Training repo exists:', training_repo.exists())
print('Training notebook exists:', training_notebook.exists())
print('Target wake word:', target_word)

# %% [markdown]
# ## What to open
#
# Open the real training notebook here:
#
# `/Users/filippospirpilidis/Projects/wakewords-models/jupiter/micro-wake-word/notebooks/basic_training_notebook.ipynb`
#
# Then change the target phrase from `hey Friday` to `hey Clio`.

# %%
expected_output = training_repo / 'trained_models' / 'wakeword' / 'tflite_stream_state_internal_quant' / 'stream_state_internal_quant.tflite'
final_model = workspace_repo / 'hey_clio' / 'hey_clio.tflite'

print('Expected training output:', expected_output)
print('Final destination:', final_model)

# %% [markdown]
# ## Compatibility reminders
#
# - Use `sys.executable` in notebook shell commands.
# - Use `curl -L` instead of `wget` on macOS.
# - If needed, pin `datasets` to `<4.0`.
# - Install `tensorboard` if training requires it.
# - Keep the `train.py` NumPy compatibility fix in mind if validation crashes.
